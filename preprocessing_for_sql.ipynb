# %%
import pandas as pd
import numpy as np

# %%
case = pd.read_csv('./data/csv/Case.csv').drop(columns=['Unnamed: 0', '등록년월', 'review_size', 'review_mean', 'review_count', 'final_score', 'Test', 'Rank',
                                                        '지원보드규격표준-ATX', '지원보드규격Micro-ATX', '지원보드규격표준-ITX', '지원보드규격Mini-ITX'])
case.rename(columns={'id':'product_id','name':'product_name', 'image':'product_image', 'price':'product_price', 'score':'review_score', 
                    'mall_review':'review_score_count', '제조회사':'company_name', '케이스 크기':'case_size', '지원파워규격':'case_power'}, inplace=True)
case['review_score_count'] = case['review_score_count'].apply(lambda x : x[1:-1].replace(',',''))
case['product_price']=case['product_price'].astype(int)
case['review_score_count']=case['review_score_count'].astype(int)
case
# Out:
#      product_id                               product_name  \
# 0      10423167                  마이크로닉스 Master M60 메쉬 (블랙)
# 1      11884207        darkFlash DLX21 RGB MESH 강화유리 (화이트)
# 2      12192788               마이크로닉스 EM1-Woofer 강화유리 (화이트)
# 3      13658789              앱코 SUITMASTER P1000 강화유리 (블랙)
# 4      12668456                      마이크로닉스 COOLMAX 베이비 샤크
# ..          ...                                        ...
# 790     5509753                 써멀테이크 View 71 강화유리 RGB 에디션
# 791    10901520      쿨러마스터 MasterBox H500P MESH WHITE ARGB
# 792     9234567                    NZXT H710 (Matte Black)
# 793     4322631         리안리 PC-O8 화이트 Mirror Painting Ver.
# 794     6707788  Fractal Design Define R6C 강화유리 (Blackout)
#
#                                          product_image  product_price  \
# 0    https://img.danawa.com/prod_img/500000/167/423...          42300
# 1    https://img.danawa.com/prod_img/500000/207/884...         103000
# ...

# %%
cooler = pd.read_csv('./data/csv/Cooler.csv').drop(columns=['Unnamed: 0', '등록년월', 'review_size', 'review_mean', 'review_count', 'final_score', 'Test', 
                                                            'Rank','인텔 소켓LGA1700', '인텔 소켓LGA1200', '인텔 소켓LGA115x','인텔 소켓LGA2066', '인텔 소켓LGA2011-V3', 
                                                            '인텔 소켓LGA775', '인텔 소켓LGA2011','인텔 소켓LGA1366', 'AMD 소켓AM4', 'AMD 소켓AM5', 'AMD 소켓FMx/AMx(AM1/4외)',
                                                            'AMD 소켓sTRX4', 'AMD 소켓TR4', 'AMD 소켓AM1'])
cooler.rename(columns={'id':'product_id','name':'product_name', 'image':'product_image', 'price':'product_price', 'score':'review_score', 
                    'mall_review':'review_score_count', '제조회사':'company_name', '냉각 방식':'cooling_type', '상세정보쿨러 높이':'cooler_height',
                    '상세정보TDP':'cooler_tdp', '상세정보팬 크기':'cooler_fan_size'}, inplace=True)
cooler['review_score_count'] = cooler['review_score_count'].apply(lambda x : x[1:-1].replace(',',''))
cooler['product_price']=cooler['product_price'].astype(int)
cooler['review_score_count']=cooler['review_score_count'].astype(int)
cooler
# Out:
#      product_id                              product_name  \
# 0      10854153                        AMD Wraith Stealth
# 1       5647865                    장우컴퍼니 JW-HTK01 M.2 방열판
# 2       9642285                   darkFlash C6S RGB (화이트)
# 3       9723438                         잘만 ZM-STC8 (1.5g)
# 4       6564470                             샤칸 XTC-4 (4g)
# ..          ...                                       ...
# 836     3772008                   쿨러마스터 MASTERAIR MAKER 8
# 837     4704683                 ARCTIC Liquid Freezer 360
# 838     6565615   CORSAIR HYDRO SERIES H100i RGB PLATINUM
# 839     9662934  쿨러마스터 MasterLiquid ML360P SILVER EDITION
# 840    15333881         NZXT KRAKEN Z53 RGB (Matte Black)
#
#                                          product_image  product_price  \
# 0    https://img.danawa.com/prod_img/500000/153/854...            960
# 1    https://img.danawa.com/prod_img/500000/865/647...           1200
# ...

# %%
cpu = pd.read_csv('./data/csv/CPU.csv').drop(columns=['Unnamed: 0', '등록년월', 'review_size', 'review_mean', 'review_count', 'final_score', 'Test', 'Rank'])
cpu.rename(columns={'id':'product_id','name':'product_name', 'image':'product_image', 'price':'product_price', 'score':'review_score', 
                    'mall_review':'review_score_count', '제조회사':'company_name', 'AMD CPU종류':'amd_cpu_category', '소켓 구분':'cpu_socket', 
                    '세대 구분':'cpu_gen', '인텔 CPU종류':'intel_cpu_category', '사양TDP':'cpu_tdp', '사양최대 클럭':'cpu_maximum_clock'}, inplace=True)
cpu['review_score_count'] = cpu['review_score_count'].apply(lambda x : x[1:-1].replace(',',''))
cpu['product_price']=cpu['product_price'].astype(int)
cpu['review_score_count']=cpu['review_score_count'].astype(int)
cpu
# Out:
#      product_id                           product_name  \
# 0      12625265     AMD 라이젠5-4세대 5600X (버미어) (멀티팩(정품))
# 1      12621851          AMD 라이젠5-4세대 5600X (버미어) (정품)
# 2       4148314               인텔 펜티엄 E5200 (울프데일) (중고)
# 3      12487424      인텔 코어i3-10세대 10100F (코멧레이크S) (정품)
# 4      12622091          AMD 라이젠9-4세대 5900X (버미어) (정품)
# ..          ...                                    ...
# 166     6705214  인텔 코어i5-9세대 9600K (커피레이크-R) (벌크 + 쿨러)
# 167     7892803      인텔 코어i7-9세대 9700KF (커피레이크-R) (벌크)
# 168     5627038     인텔 코어i3-8세대 8100 (커피레이크) (병행수입 박스)
# 169     4370096        인텔 제온 E5-2630 v4 (브로드웰-EP) (정품)
# 170     6566789  인텔 코어i9-9세대 9900K (커피레이크-R) (병행수입 박스)
#
#                                          product_image  product_price  \
# 0    https://img.danawa.com/prod_img/500000/265/625...         216730
# 1    https://img.danawa.com/prod_img/500000/851/621...         206960
# 2    https://img.danawa.com/prod_img/500000/314/148...           1410
# ...

# %%
gpu = pd.read_csv('./data/csv/GPU.csv').drop(columns=['Unnamed: 0', '등록년월', 'review_size', 'review_mean', 'review_count', 'final_score', 'Test', 'Rank'])
gpu.rename(columns={'id':'product_id','name':'product_name', 'image':'product_image', 'price':'product_price', 'score':'review_score', 
                    'mall_review':'review_score_count', '제조회사':'company_name', '전력 관련권장 파워용량':'recommend_power'}, inplace=True)
gpu['review_score_count'] = gpu['review_score_count'].apply(lambda x : x[1:-1].replace(',',''))
gpu['product_price']=gpu['product_price'].astype(int)
gpu['review_score_count']=gpu['review_score_count'].astype(int)
gpu
# Out:
#      product_id                                       product_name  \
# 0      13463144           이엠텍 지포스 RTX 3060 STORM X Dual OC D6 12GB
# 1      12822224         이엠텍 지포스 RTX 3060 Ti STORM X Dual OC D6 8GB
# 2      13470908              MSI 지포스 RTX 3060 게이밍 X D6 12GB 트윈프로져8
# 3      13462442  이엠텍 지포스 GTX 1660 SUPER STORM X Dual BASIC OC D...
# 4       9790371             MSI 지포스 GTX 1660 SUPER 벤투스 S OC D6 6GB
# ..          ...                                                ...
# 463    12505235      GIGABYTE 지포스 RTX 3090 VISION OC D6X 24GB 제이씨현
# 464     2882099                              매트록스 C680 D5 2GB 코트록스
# 465    16207859   EVGA 지포스 RTX 3080 FTW3 ULTRA GAMING D6X 12GB LHR
# 466    14443649      ZOTAC GAMING 지포스 RTX 3080 Trinity OC D6X 10GB
# 467     6839308                        NVIDIA 쿼드로 RTX 6000 D6 24GB
#
#                                          product_image  product_price  \
# 0    https://img.danawa.com/prod_img/500000/144/463...         447200
# ...

# %%
hdd = pd.read_csv('./data/csv/HDD.csv').drop(columns=['Unnamed: 0', '등록년월', 'review_size', 'review_mean', 'review_count', 'final_score', 
                                                      'Test', 'Rank','내구성/소음작업부하량','A/S 정보2년', 'KC인증적합성평가인증', 'KC인증안전확인인증', 
                                                      '내구성/소음소음(유휴/탐색)', '부가기능헬륨충전','부가기능RV센서', '내구성/소음사용보증', 'A/S 정보5년', 
                                                      'A/S 정보데이터 복구 3년', '부가기능DSA','부가기능S.M.A.R.T 지원', 'A/S 정보3년', '부가기능저전력', 
                                                      '부가기능ISE', '부가기능SED','A/S 정보데이터 복구 2년', 'A/S 정보1년'])
hdd.rename(columns={'id':'product_id','name':'product_name', 'image':'product_image', 'price':'product_price', 'score':'review_score', 
                    'mall_review':'review_score_count', '제조회사':'company_name', '제품 분류':'hdd_category','디스크 크기':'disk_size',
                    '디스크 용량':'disk_capacity','인터페이스':'hdd_interface', '회전수':'hdd_rpm', '버퍼 용량':'buffer_capacity',
                    '전송 속도':'transfer_speed','기록방식':'record_system', '디스크 수':'disk_count','두께':'hdd_thickness'}, inplace=True)
hdd['review_score_count'] = hdd['review_score_count'].apply(lambda x : x[1:-1].replace(',',''))
hdd['product_price']=hdd['product_price'].astype(int)
hdd['review_score_count']=hdd['review_score_count'].astype(int)
hdd
# Out:
#     product_id                                       product_name  \
# 0      6545078     Seagate BarraCuda 7200/256M (ST2000DM008, 2TB)
# 1      1706996   Western Digital WD BLUE 7200/64M (WD10EZEX, 1TB)
# 2      5173062     Seagate BarraCuda 5400/256M (ST4000DM004, 4TB)
# 3      5764992     Seagate BarraCuda 5400/256M (ST8000DM004, 8TB)
# 4      9721383  Seagate BarraCuda 5400/256M/해외구매 (ST8000DM004,...
# ..         ...                                                ...
# 72     6295629                 도시바 X300 7200/256M (HDWR11A, 10TB)
# 73     7617292  Western Digital Ultrastar DC HC530 패키지 7200/51...
# 74     6456701   Seagate IronWolf 7200/256M (ST14000VN0008, 14TB)
# 75    12068387  Western Digital WD Ultrastar DC HC550 7200/512...
# 76     9725427   Seagate Exos X16 7200/256M (ST16000NM001G, 16TB)
#
#                                         product_image  product_price  \
# 0   https://img.danawa.com/prod_img/500000/078/545...          82000
# ...

# %%
mainboard = pd.read_csv('./data/csv/Mainboard.csv').drop(columns=['Unnamed: 0', '등록년월', 'review_size', 'review_mean', 'review_count', 'final_score', 
                                                      'Test', 'Rank'])
mainboard.rename(columns={'id':'product_id','name':'product_name', 'image':'product_image', 'price':'product_price', 'score':'review_score', 
                    'mall_review':'review_score_count', '제조회사':'company_name','기본 사양CPU 소켓':'cpu_socket_type', '메모리메모리 종류':'memory_type'}, inplace=True)
mainboard['review_score_count'] = mainboard['review_score_count'].apply(lambda x : x[1:-1].replace(',',''))
mainboard['product_price']=mainboard['product_price'].astype(int)
mainboard['review_score_count']=mainboard['review_score_count'].astype(int)
mainboard
# Out:
#      product_id                                product_name  \
# 0      12276353            GIGABYTE B550M AORUS PRO-P 피씨디렉트
# 1       7452148                 ASUS EX A320M-GAMING 대원씨티에스
# 2      13289171                       ASRock B560M PRO4 에즈윈
# 3       6948952                   ASRock A320M-HDV R4.0 에즈윈
# 4      11578325                      MSI MAG B550M 박격포 WiFi
# ..          ...                                         ...
# 430     9660786                   ASUS PRIME X299-A II 아이보라
# 431     8502987        GIGABYTE X570 I AORUS PRO WiFi 피씨디렉트
# 432     6063646      GIGABYTE X470 AORUS Gaming 7 WiFi 제이씨현
# 433    15673778  ASUS ROG MAXIMUS Z690 EXTREME GLACIAL 아이보라
# 434    10132605           GIGABYTE TRX40 AORUS XTREME 피씨디렉트
#
#                                          product_image  product_price  \
# 0    https://img.danawa.com/prod_img/500000/353/276...         290550
# 1    https://img.danawa.com/prod_img/500000/148/452...         138110
# ...

# %%
power = pd.read_csv('./data/csv/Power.csv').drop(columns=['Unnamed: 0', '등록년월', 'review_size', 'review_mean', 'review_count', 'final_score', 
                                                      'Test', 'Rank'])
power.rename(columns={'id':'product_id','name':'product_name', 'image':'product_image', 'price':'product_price', 'score':'review_score', 
                    'mall_review':'review_score_count', '제조회사':'company_name', '정격출력':'power_rate', '[커넥터]케이블연결':'cable_type', '제품 분류':'power_category'}, inplace=True)
power['review_score_count'] = power['review_score_count'].apply(lambda x : x[1:-1].replace(',',''))
power['product_price']=power['product_price'].astype(int)
power['review_score_count']=power['review_score_count'].astype(int)
power
# Out:
#      product_id                                       product_name  \
# 0       6216861                                     잘만 EcoMax 500W
# 1       1928750              마이크로닉스 Classic II 600W 80PLUS 230V EU
# 2       9326622   마이크로닉스 Classic II 750W 80PLUS Bronze 230V EU HDB
# 3       1928673              마이크로닉스 Classic II 500W 80PLUS 230V EU
# 4      14677028  마이크로닉스 Classic II 풀체인지 600W 80PLUS BRONZE 230V EU
# ..          ...                                                ...
# 366     8038282   앱코 SUITMASTER ULTIMATE 1200W RGB 80PLUS PLATINUM
# 367     6461871                   마이크로닉스 ASTRO Platinum 1050W 풀모듈러
# 368     2832136                     CORSAIR HX850i 80PLUS PLATINUM
# 369     7471096  시소닉 PRIME SnowSilent Titanium SSR-750TR Full M...
# 370     1808683                            Antec HCP-1000 Platinum
#
#                                          product_image  product_price  \
# 0    https://img.danawa.com/prod_img/500000/861/216...          36910
# ...

# %%
ram = pd.read_csv('./data/csv/RAM.csv').drop(columns=['Unnamed: 0', '등록년월', 'review_size', 'review_mean','램개수'])
ram.rename(columns={'id':'product_id','name':'product_name', 'image':'product_image', 'price':'product_price', 'score':'review_score', 
                    'mall_review':'review_score_count', '제조회사':'company_name', '메모리 용량':'memory_size'}, inplace=True)
ram
# Out:
#     product_id                           product_name  \
# 0     11028636                  삼성전자 DDR4-3200 (32GB)
# 1     11790199                  삼성전자 DDR4-3200 (16GB)
# 2     11541857                   삼성전자 DDR4-3200 (8GB)
# 3     10294092     마이크론 Crucial DDR4-3200 CL22 (16GB)
# 4     10294017      마이크론 Crucial DDR4-3200 CL22 (8GB)
# 5     10881360              삼성전자 노트북 DDR4-3200 (32GB)
# 6     11397141              삼성전자 노트북 DDR4-3200 (16GB)
# 7     10853625               삼성전자 노트북 DDR4-3200 (8GB)
# 8      5549101                삼성전자 DDR3-1600 중고 (8GB)
# 9      5545241                삼성전자 DDR3-1600 중고 (4GB)
# 10     8158972                삼성전자 DDR4-2666 중고 (8GB)
# 11     6168338     GeIL DDR4-2666 CL19 PRISTINE (8GB)
# 12    10610796  마이크론 Crucial 노트북 DDR4-3200 CL22 (8GB)
# 13     5215088    타무즈 노트북 DDR3L-1600 CL11 1.35V (8GB)
# 14     4838666               타무즈 DDR3-1600 CL11 (8GB)
# 15     6018766               타무즈 DDR4-2666 CL19 (8GB)
# ...

# %%
ssd = pd.read_csv('./data/csv/SSD.csv').drop(columns=['Unnamed: 0', '등록년월', 'review_size', 'review_mean', 'review_count', 'final_score', 
                                                      'Test', 'Rank'])
ssd.rename(columns={'id':'product_id','name':'product_name', 'image':'product_image', 'price':'product_price', 'score':'review_score', 
                    'mall_review':'review_score_count', '제조회사':'company_name', '[기본사양]용량':'ssd_capacity', '[기본사양]RAM 타입':'ssd_type'}, inplace=True)
ssd['review_score_count'] = ssd['review_score_count'].apply(lambda x : x[1:-1].replace(',',''))
ssd['product_price']=ssd['product_price'].astype(int)
ssd['review_score_count']=ssd['review_score_count'].astype(int)
ssd
# Out:
#      product_id                                    product_name  \
# 0      13161353                SK하이닉스 Gold P31 M.2 NVMe (500GB)
# 1      10120452  Western Digital WD BLUE SN550 M.2 NVMe (500GB)
# 2      13344977                삼성전자 PM9A1 M.2 NVMe 병행수입 (512GB)
# 3       5791864               마이크론 Crucial MX500 대원씨티에스 (500GB)
# 4      10034457               리뷰안 M.2 PCIe 어댑터 (EX2M1) (SSD미포함)
# ..          ...                                             ...
# 254     6754546                              삼성전자 860 QVO (4TB)
# 255     6163284      Western Digital WD BLACK 3D M.2 NVMe (1TB)
# 256     5834144                              삼성전자 860 PRO (1TB)
# 257     6096657                     삼성전자 970 EVO M.2 NVMe (2TB)
# 258     5831329                 인텔 Optane SSD 900P PCIe (480GB)
#
#                                          product_image  product_price  \
# 0    https://img.danawa.com/prod_img/500000/353/161...          79000
# ...

# %%
review_df = pd.read_csv('./data/csv/review_shuffle_data.csv')
review_df.rename(columns={'id':'product_id', 'comment':'review_comment', 'time':'review_time', 'good':'review_good_count','bad':'review_bad_count'}, inplace=True)
review_df
# Out:
#        product_id                                     review_comment  \
# 0        12487424                        구매해서 장착했더니 날라 다니네요. 역시 좋네요.
# 1        11593289       인텔 CPU 할인 정보입니다.\r\nhttp://bit.do/blogme7702
# 2        15302858  60만원 후반 70만원 초반도 비싸다고 느겼는데 말도 안되는 소리하고 앉아있네!\r...
# 3        12701975                                이거 단종인가요?? 구경할수 없네용
# 4        14776451                        하루만에 5만원이 올라?ㅋㅋㅋㅋ 여기 코인시장임?
# ...           ...                                                ...
# 69581    13190711            QLC로 토렌트 셰어용으로 몇달 쓰니까 사요나라임.. 최소 TLC..
# 69582    12822224                 가격봐ㅋㅋㅋ 채굴꾼들 죄다 싹 망해서 ㅈ됐으면좋겠다 새해기원!
# 69583     6534868  코잇컴 - 여기선 사지 말아요~ 낮은가격으로 상위 노출시켜서 컴부품 다른데서 사다말...
# 69584    15594887  인텔빠들 현실 자각하셈\r\n\r\n암드가 cpu시장에서 나온지 인텔에 비해서 그렇...
# 69585    11308485  라이젠 2700x쓰다 혹시나하는 맘에 바꿔봤는데 캐드 , 스케치업 , 루미온 돌려본...
#
#                 review_time  review_good_count  review_bad_count
# 0      2021.09.12. 20:13:18                0.0               0.0
# ...

# %%
case.to_csv('./data/renewal/case.csv', index=False)
cooler.to_csv('./data/renewal/cooler.csv', index=False)
cpu.to_csv('./data/renewal/cpu.csv', index=False)
gpu.to_csv('./data/renewal/gpu.csv', index=False)
hdd.to_csv('./data/renewal/hdd.csv', index=False)
mainboard.to_csv('./data/renewal/mainboard.csv', index=False)
power.to_csv('./data/renewal/power.csv', index=False)
ram.to_csv('./data/renewal/ram.csv', index=False)
review_df.to_csv('./data/renewal/review.csv', index=False)
ssd.to_csv('./data/renewal/ssd.csv', index=False)
